# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from matplotlib import style

# %%
diabetes_df=pd.read_csv("health care diabetes.csv")
diabetes_df.shape
# Out:
# (768, 9)

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.isnull().value_counts()
# Out:
# Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI    DiabetesPedigreeFunction  Age    Outcome
# False        False    False          False          False    False  False                     False  False      768
# dtype: int64

# %%
diabetes_df['Pregnancies'].value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %%
plt.figure(figsize=(15,9))
a=diabetes_df['Glucose']
plt.hist(a,bins=10)
plt.show()

# %%
plt.figure(figsize=(15,9))
a=diabetes_df['BloodPressure']
plt.hist(a,bins=10)
plt.show()

# %%
plt.figure(figsize=(15,9))
a=diabetes_df['SkinThickness']
plt.hist(a,bins=10)
plt.show()

# %%
plt.figure(figsize=(15,9))
a=diabetes_df['Insulin']
plt.hist(a,bins=10)
plt.show()

# %%
plt.figure(figsize=(15,9))
a=diabetes_df['BMI']
plt.hist(a,bins=10)
plt.show()

# %%
plt.figure(figsize=(15,9))
a=diabetes_df['Age']
plt.hist(a,bins=10)
plt.show()

# %%
plt.figure(figsize=(25,10))
style.use('ggplot')
diabetes_df['Glucose'].value_counts().plot(kind='bar',xlabel='Glucose',ylabel='frequency')
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='frequency'>

# %%
plt.figure(figsize=(25,10))
style.use('ggplot')
diabetes_df['BloodPressure'].value_counts().plot(kind='bar',xlabel='BloodPressure',ylabel='frequency')
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='frequency'>

# %%
plt.figure(figsize=(25,10))
style.use('ggplot')
diabetes_df['SkinThickness'].value_counts().plot(kind='bar',xlabel='SkinThickness',ylabel='frequency')
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='frequency'>

# %%
plt.figure(figsize=(30,10))
style.use('ggplot')
diabetes_df['Insulin'].value_counts().plot(kind='bar',xlabel='Insulin',ylabel='frequency')
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='frequency'>

# %%
plt.figure(figsize=(25,10))
style.use('ggplot')
diabetes_df['BMI'].value_counts().plot(kind='bar',xlabel='BMI',ylabel='frequency')
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='frequency'>

# %%
plt.figure(figsize=(25,10))
style.use('ggplot')
diabetes_df['DiabetesPedigreeFunction'].value_counts().plot(kind='bar',xlabel='DiabetesPedigreeFunction',ylabel='frequency')
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='frequency'>

# %%
corr=diabetes_df.corr()
corr
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
plt.figure(figsize=(7,10))
sns.set_style('whitegrid')
sns.heatmap(diabetes_df,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(diabetes_df)
